# %%
#pip install pydantic
# Out:
# Collecting pydantic
#   Downloading pydantic-2.11.1-py3-none-any.whl (442 kB)
#                                               0.0/442.6 kB ? eta -:--:--
#      ---                                   41.0/442.6 kB 653.6 kB/s eta 0:00:01
#      -------                               92.2/442.6 kB 871.5 kB/s eta 0:00:01
#      ------------                           143.4/442.6 kB 1.1 MB/s eta 0:00:01
#      ------------                           143.4/442.6 kB 1.1 MB/s eta 0:00:01
#      ---------------------                  256.0/442.6 kB 1.1 MB/s eta 0:00:01
#      -----------------------------          337.9/442.6 kB 1.2 MB/s eta 0:00:01
#      -----------------------------------    409.6/442.6 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 442.6/442.6 kB 1.2 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0 (from pydantic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.0 (from pydantic)
#   Downloading pydantic_core-2.33.0-cp311-cp311-win_amd64.whl (1.9 MB)
#                                               0.0/1.9 MB ? eta -:--:--
#      -                                        0.1/1.9 MB 1.7 MB/s eta 0:00:02
#      --                                       0.1/1.9 MB 1.7 MB/s eta 0:00:02
#      ----                                     0.2/1.9 MB 2.0 MB/s eta 0:00:01
#      -----                                    0.3/1.9 MB 1.8 MB/s eta 0:00:01
#      -----                                    0.3/1.9 MB 1.8 MB/s eta 0:00:01
#      -----                                    0.3/1.9 MB 1.1 MB/s eta 0:00:02
#      -------                                  0.4/1.9 MB 1.3 MB/s eta 0:00:02
#      -------                                  0.4/1.9 MB 1.3 MB/s eta 0:00:02
#      ---------                                0.5/1.9 MB 1.2 MB/s eta 0:00:02
#      ----------                               0.5/1.9 MB 1.2 MB/s eta 0:00:02
#      ----------                               0.5/1.9 MB 1.1 MB/s eta 0:00:02
#      ----------                               0.5/1.9 MB 1.1 MB/s eta 0:00:02
#      ------------                             0.6/1.9 MB 1.0 MB/s eta 0:00:02
#      -------------                            0.6/1.9 MB 999.4 kB/s eta 0:00:02
#      -------------                            0.7/1.9 MB 960.0 kB/s eta 0:00:02
#      -------------                            0.7/1.9 MB 946.8 kB/s eta 0:00:02
#      --------------                           0.7/1.9 MB 935.8 kB/s eta 0:00:02
#      ---------------                          0.7/1.9 MB 925.1 kB/s eta 0:00:02
#      ---------------                          0.8/1.9 MB 927.5 kB/s eta 0:00:02
#      -----------------                        0.8/1.9 MB 919.4 kB/s eta 0:00:02
#      -----------------                        0.9/1.9 MB 907.1 kB/s eta 0:00:02
#      ------------------                       0.9/1.9 MB 886.9 kB/s eta 0:00:02
#      -------------------                      0.9/1.9 MB 890.0 kB/s eta 0:00:02
#      --------------------                     1.0/1.9 MB 886.4 kB/s eta 0:00:02
#      ---------------------                    1.0/1.9 MB 877.0 kB/s eta 0:00:02
#      ---------------------                    1.1/1.9 MB 879.9 kB/s eta 0:00:02
#      ----------------------                   1.1/1.9 MB 871.3 kB/s eta 0:00:01
#      -----------------------                  1.1/1.9 MB 881.6 kB/s eta 0:00:01
#      -----------------------                  1.1/1.9 MB 848.2 kB/s eta 0:00:01
#      ------------------------                 1.2/1.9 MB 846.6 kB/s eta 0:00:01
#      ------------------------                 1.2/1.9 MB 842.5 kB/s eta 0:00:01
#      -------------------------                1.2/1.9 MB 843.5 kB/s eta 0:00:01
#      --------------------------               1.3/1.9 MB 839.7 kB/s eta 0:00:01
#      --------------------------               1.3/1.9 MB 839.7 kB/s eta 0:00:01
#      ---------------------------              1.3/1.9 MB 828.7 kB/s eta 0:00:01
#      ----------------------------             1.4/1.9 MB 829.9 kB/s eta 0:00:01
#      ----------------------------             1.4/1.9 MB 817.8 kB/s eta 0:00:01
#      ----------------------------             1.4/1.9 MB 809.0 kB/s eta 0:00:01
#      ------------------------------           1.5/1.9 MB 802.5 kB/s eta 0:00:01
#      ------------------------------           1.5/1.9 MB 805.2 kB/s eta 0:00:01
#      -------------------------------          1.5/1.9 MB 806.9 kB/s eta 0:00:01
#      --------------------------------         1.6/1.9 MB 803.6 kB/s eta 0:00:01
#      --------------------------------         1.6/1.9 MB 800.0 kB/s eta 0:00:01
#      ---------------------------------        1.6/1.9 MB 797.5 kB/s eta 0:00:01
#      ---------------------------------        1.6/1.9 MB 794.6 kB/s eta 0:00:01
#      ----------------------------------       1.7/1.9 MB 795.1 kB/s eta 0:00:01
#      -----------------------------------      1.7/1.9 MB 792.0 kB/s eta 0:00:01
#      ------------------------------------     1.8/1.9 MB 794.8 kB/s eta 0:00:01
#      ------------------------------------     1.8/1.9 MB 791.9 kB/s eta 0:00:01
#      -------------------------------------    1.8/1.9 MB 792.8 kB/s eta 0:00:01
#      --------------------------------------   1.9/1.9 MB 796.2 kB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 787.4 kB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 794.2 kB/s eta 0:00:01
#      ---------------------------------------- 1.9/1.9 MB 785.6 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hp\appdata\roaming\python\python311\site-packages (from pydantic) (4.13.0)
# Collecting typing-inspection>=0.4.0 (from pydantic)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, annotated-types, pydantic
# Successfully installed annotated-types-0.7.0 pydantic-2.11.1 pydantic-core-2.33.0 typing-inspection-0.4.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### The logic behind the three classes
#
# * Materiel Class: Represents a single material component in a garment construction
#
#     - fabric_type: Optional technical specification (e.g "GORE-TEX", CORDURA")
#     - name: Base material name (e.g. "cotton", "polyster")
#     - percentage: Composition percentage in the construction element
#
# * ConstructionElement Class: Represents a distinct part of a garment's construction
#
#     - name: Component identifier (e.g., "Main", "Lining", "Pocket lining")
#
#     - colors: List of color codes associated with this element
#
#     - materials: List of Material objects making up this element
#
#     - weight: Weight specification (e.g., "220 g/m²")
#
# * Garment Class: Represents a complete garment product
#
#     - code: Unique product identifier
#
#     - category: Product type (e.g., "JACKET", "TSHIRT")
#
#     - construction: List of all construction elements in the garment

# %%
import csv
import re
from typing import List, Optional
from pydantic import BaseModel, Field, ValidationError

class Material(BaseModel):
    fabric_type: Optional[str] = None
    name: str
    percentage: int

class ConstructionElement(BaseModel):
    name: str
    colors: List[str] = Field(default_factory=list)
    materials: List[Material]
    weight: str

class Garment(BaseModel):
    code: str
    category: str
    construction: List[ConstructionElement]

def clean_text(text: str) -> str:
    """Enhanced cleaning with comprehensive weight normalization"""
    replacements = {
        "Â®": "®", "Ã©": "é", "Â²": "²", 
        "gr": "g", "Gr": "g", "GR": "g",
        "CORDURAÂ®": "CORDURA®",
        "REPREVEÂ®": "REPREVE®",
        "g/m2": "g/m²"  # Add explicit normalization for g/m2
    }
    for old, new in replacements.items():
        text = text.replace(old, new)
    text = re.sub(r'\s*%\s*', '%', text)
    return re.sub(r'\s+', ' ', text).strip()

def parse_construction_details(detail_text: str) -> List[dict]:
    """Parse construction details with enhanced color and element grouping"""
    elements = []
    detail_text = clean_text(detail_text)
    
    # Split segments while preserving color contexts
    segments = re.split(r'(?<!\bCol\.)(?<!\bCol)\s*[.;](?!\s*\d)', detail_text)
    
    current_colors = []
    
    for segment in segments:
        segment = segment.strip()
        if not segment:
            continue

        # Extract colors first
        colors, cleaned_segment = parse_colors(segment)
        current_colors = colors if colors else current_colors

        # Handle element name and details
        if ':' in cleaned_segment:
            name_part, detail_part = cleaned_segment.split(':', 1)
            name = name_part.strip()
            details = detail_part.strip()
        else:
            name = "Main"
            details = cleaned_segment

        # Extract weight and materials
        materials, weight = parse_materials_and_weight(details)

        if materials:
            elements.append({
                "name": name,
                "materials": [m.model_dump() for m in materials],
                "weight": weight,
                "colors": current_colors.copy()
            })
            current_colors = []

    return elements

def parse_materials_and_weight(material_text: str) -> tuple[List[Material], str]:
    """Improved material parser that extracts weight from material descriptions"""
    materials = []
    weight = ""
    
    # First check for separate weight specification in the text
    weight_match = re.search(r'(\d+\s*g(?:/m²)?)', material_text)
    if weight_match:
        weight = weight_match.group(1)
        # Remove standalone weight from material text
        material_text = material_text.replace(weight_match.group(0), '').strip(' ,')
    
    # Detect and extract fabric type prefix
    fabric_type = None
    fabric_match = re.match(r'^([A-Za-z®.\-\s]+?)\s(?=\d+%)', material_text)
    if fabric_match:
        fabric_type = fabric_match.group(1).strip()
        material_text = material_text[len(fabric_type):].strip()

    # Split materials while preserving technical specifications
    parts = re.split(r',\s*(?=\d+%)|\s+(?=\d+%)', material_text)
    
    for part in parts:
        part = part.strip()
        if not part:
            continue
            
        # Skip if this part is just a weight specification
        if re.match(r'^\d+\s*g', part, re.IGNORECASE) and len(part.split()) <= 2:
            continue

        match = re.match(r'(\d+)%\s*(.*)', part)
        if match:
            percentage = int(match.group(1))
            name = match.group(2).strip().lower()
            
            # Extract weight from material name if present
            material_weight_match = re.search(r'(\d+\s*g(?:/m²)?)', name)
            if material_weight_match:
                if not weight:  # Only use if we don't already have a weight
                    weight = material_weight_match.group(1)
                # Remove weight from material name
                name = name.replace(material_weight_match.group(0), '').strip(' ,')
            
            # Handle specific location mentions in the weight
            body_sleeves_match = re.search(r'in\s+body\s+and\s+sleeves', name)
            if body_sleeves_match:
                location_info = body_sleeves_match.group(0)
                name = name.replace(location_info, '').strip()
                # Attach the location info to the weight instead
                if weight:
                    weight += f" {location_info}"
            
            # Handle nested materials
            if '(' in name:
                name, nested = name.split('(', 1)
                nested = nested.rstrip(')').strip()
                nested_match = re.match(r'(\d+)%\s*(.*)', nested)
                if nested_match:
                    materials.append(Material(
                        name=nested_match.group(2).strip(),
                        percentage=int(nested_match.group(1)),
                        fabric_type=name.strip()
                    ))

            materials.append(Material(
                name=name,
                percentage=percentage,
                fabric_type=fabric_type
            ))

    return materials, weight

def parse_colors(segment: str) -> tuple[List[str], str]:
    """Enhanced color extraction with plural and abbreviated forms"""
    color_pattern = r'(?i)(?:Colou?rs?|Col\.?)(?:s|)\s*([\d\s,and]+?)(?=\s*\d+%|:|;|\.)'
    match = re.search(color_pattern, segment)
    if not match:
        return [], segment
    
    color_str = match.group(1).strip()
    color_str = re.sub(r'[^\d\s,and]+$', '', color_str)
    colors = [c.strip() for c in re.split(r',|\s+and\s+', color_str) if c.strip()]
    
    cleaned_segment = re.sub(color_pattern, '', segment, flags=re.IGNORECASE)
    return colors, cleaned_segment.strip(' :;,.')

def parse_garments_csv(file_path: str) -> List[Garment]:
    garments = []
    with open(file_path, 'r', encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) < 3:
                continue
                
            code = row[0].strip()
            category = row[1].strip()
            details = clean_text(row[2])
            
            try:
                construction = parse_construction_details(details)
                garment = Garment.model_validate({
                    "code": code,
                    "category": category,
                    "construction": construction
                })
                garments.append(garment)
            except ValidationError as e:
                print(f"Error parsing row {row}: {e}")

    return garments

# %%
# Path to your CSV file
file_path = r"C:\Users\HP\Downloads\care_labels.csv"
garments = parse_garments_csv(file_path)

l = list()
# Display parsed garments
for garment in garments:
    print(garment)
    l.append(garment)
# Out:
# code='product_id' category='product_category' construction=[]
# code='#113' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=40), Material(fabric_type=None, name='polyester', percentage=60)], weight='290 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=53), Material(fabric_type=None, name='polyester', percentage=47)], weight='290 g/m²'), ConstructionElement(name='Reinforcement Knee', colors=[], materials=[Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='205 g/m²')]
# code='#212' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=52), Material(fabric_type=None, name='polyamide', percentage=48)], weight='240 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='')]
# code='#213' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=40), Material(fabric_type=None, name='polyester', percentage=60)], weight='290 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=53), Material(fabric_type=None, name='polyester', percentage=47)], weight='290 g/m²'), ConstructionElement(name='Reinforcement Knee', colors=[], materials=[Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='205 g/m²')]
# code='#214' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=60), Material(fabric_type=None, name='polyester', percentage=40)], weight='340 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='')]
# code='#312' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=52), Material(fabric_type=None, name='polyamide', percentage=48)], weight='240 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='')]
# code='#1100' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='220 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Mesh', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='367 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1102' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='220 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Mesh', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='367 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1106' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='recycled polyamide', percentage=100)], weight='175 g'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='190 g'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='repreve® recycled polyester', percentage=90), Material(fabric_type=None, name='recycled polyester,', percentage=10)], weight='120 g in body and sleeves'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#1107' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='220 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Mesh', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='367 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1112' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='recycled polyamide', percentage=100)], weight='175 g'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='190 g'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='repreve® recycled polyester', percentage=90), Material(fabric_type=None, name='recycled polyester,', percentage=10)], weight='120 g in body and sleeves'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#1117' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='recycled polyamide', percentage=100)], weight='175 g'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='190 g'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='repreve® recycled polyester', percentage=90), Material(fabric_type=None, name='recycled polyester,', percentage=10)], weight='120 g in body and sleeves'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#1127' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='220 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Mesh', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='367 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1130' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='230 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²')]
# code='#1132' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='230 g/m²'), ConstructionElement(name='Contrast main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='250 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='305 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1137' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='230 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Mesh', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='367 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1138' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='230 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Padding', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='120 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²'), ConstructionElement(name='Collar lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='350 g/m²')]
# code='#1148' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='175 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='220 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight=''), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1158' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='175 g'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='190 g'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='repreve® recycled polyester', percentage=90), Material(fabric_type=None, name='recycled polyester,', percentage=10)], weight='120 g in body and sleeves'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#1163' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='protal', percentage=55), Material(fabric_type=None, name='cotton', percentage=44), Material(fabric_type=None, name='antistatic, pu laminated', percentage=1)], weight='265 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=40), Material(fabric_type=None, name='viscose fr', percentage=37), Material(fabric_type=None, name='regenerated viscose', percentage=22), Material(fabric_type=None, name='antistatic', percentage=1)], weight='180 g/m²'), ConstructionElement(name='Padding', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='110 g/m²')]
# code='#1164' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=31), Material(fabric_type=None, name='modacrylic', percentage=28), Material(fabric_type=None, name='aramid kermel®', percentage=20), Material(fabric_type=None, name='cv fr', percentage=20), Material(fabric_type=None, name='antistatic', percentage=1)], weight='320 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=40), Material(fabric_type=None, name='viscose fr', percentage=37), Material(fabric_type=None, name='regenerated viscose', percentage=22), Material(fabric_type=None, name='antistatic', percentage=1)], weight='180 g/m²'), ConstructionElement(name='Padding', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='120 g/m²')]
# code='#1167' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='protal®', percentage=55), Material(fabric_type=None, name='cotton', percentage=44), Material(fabric_type=None, name='antistatic, pu laminated', percentage=1)], weight='265 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='modacrylin fr', percentage=40), Material(fabric_type=None, name='viscose fr', percentage=37), Material(fabric_type=None, name='regenerated viscose', percentage=22), Material(fabric_type=None, name='antistatic, , padding:', percentage=1), Material(fabric_type=None, name='polyester', percentage=100)], weight='180 g/m²')]
# code='#1177' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='recycled polyamide', percentage=100)], weight='175 g'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='190 g'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='repreve® recycled polyester', percentage=90), Material(fabric_type=None, name='recycled polyester,', percentage=10)], weight='120 g in body and sleeves'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#1200' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='265 g/m²'), ConstructionElement(name='Reinforcements', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²')]
# code='#1205' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=88), Material(fabric_type=None, name='elastane', percentage=12)], weight='218 g/m²')]
# code='#1207' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='265 g/m²'), ConstructionElement(name='Reinforcements', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²')]
# code='#1211' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='265g/m²')]
# code='#1218' category='JACKET' construction=[ConstructionElement(name='Material', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=88), Material(fabric_type=None, name='elastane', percentage=12)], weight='285 g/m²')]
# code='#1229' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='265 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²')]
# code='#1230' category='JACKET' construction=[ConstructionElement(name='Main Fabric', colors=[], materials=[Material(fabric_type=None, name='polyester  reinforcement: cordura®', percentage=100), Material(fabric_type=None, name='polyamide', percentage=100)], weight='265g/m²')]
# code='#1237' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester  reinforcement:', percentage=100), Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='265 g/m²')]
# code='#1247' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=88), Material(fabric_type=None, name='elastane', percentage=12)], weight='218 g/m²')]
# code='#1260' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='protal®', percentage=55), Material(fabric_type=None, name='cotton', percentage=44), Material(fabric_type=None, name='antistatic + pu laminated', percentage=1)], weight='405 g/m²')]
# code='#1300' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='150g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='305g/m²')]
# code='#1303' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='145 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='69 g/m²')]
# code='#1304' category='JACKET' construction=[ConstructionElement(name='Material', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='145 g/m²')]
# code='#1330' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='137g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='69 g/m²')]
# code='#1331' category='JACKET' construction=[ConstructionElement(name='Material', colors=[], materials=[Material(fabric_type='polyester,', name='sorona® polyester', percentage=39), Material(fabric_type=None, name='polyester,  ', percentage=100)], weight='260 g/m²')]
# code='#1347' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='137g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='69 g/m²')]
# code='#1360' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='protal', percentage=55), Material(fabric_type=None, name='cotton', percentage=44), Material(fabric_type=None, name='antistatic, pu laminated', percentage=1)], weight='265 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='meta-aramid', percentage=50), Material(fabric_type=None, name='viscose fr', percentage=50)], weight='120 g/m²')]
# code='#1361' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='protal', percentage=55), Material(fabric_type=None, name='cotton', percentage=44), Material(fabric_type=None, name='antistatic, pu laminated', percentage=1)], weight='265 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='meta-aramid', percentage=50), Material(fabric_type=None, name='viscose fr', percentage=50)], weight='120 g/m²')]
# code='#1367' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='137 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='69 g/m²')]
# code='#1539' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=61), Material(fabric_type=None, name='sorona® polyester', percentage=39)], weight='260 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=88), Material(fabric_type=None, name='elastane', percentage=12)], weight='275 g/m²')]
# code='#1549' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=47), Material(fabric_type=None, name='polyester', percentage=53)], weight='237 g/m²'), ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=61), Material(fabric_type=None, name='sorona® polyester', percentage=39)], weight='252 g/m²')]
# code='#1560' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic', percentage=1)], weight='300 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='meta-aramid', percentage=50), Material(fabric_type=None, name='viscose fr', percentage=50)], weight='120 g/m²')]
# code='#1561' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic', percentage=1)], weight='300g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='meta-aramid', percentage=50), Material(fabric_type=None, name='viscose fr', percentage=50)], weight='120 g/m²')]
# code='#1562' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=31), Material(fabric_type=None, name='modacrylic', percentage=28), Material(fabric_type=None, name='aramid kermel®', percentage=20), Material(fabric_type=None, name='cv fr', percentage=20), Material(fabric_type=None, name='antistatic', percentage=1)], weight='320 g/m²')]
# code='#1563' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='wool', percentage=68), Material(fabric_type=None, name='modacrylic fr', percentage=30), Material(fabric_type=None, name='belltron®', percentage=2)], weight='450 g/m²')]
# code='#1566' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic', percentage=1)], weight='300 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='meta-aramid', percentage=50), Material(fabric_type=None, name='viscose fr', percentage=50)], weight='120 g/m²')]
# code='#1567' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic', percentage=1)], weight='300g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='meta-aramid', percentage=50), Material(fabric_type=None, name='viscose fr', percentage=50)], weight='120 g/m²')]
# code='#1633' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=40), Material(fabric_type=None, name='polyester', percentage=60)], weight='290 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=53), Material(fabric_type=None, name='polyester', percentage=47)], weight='290 g/m²')]
# code='#1668' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='pes, 0', percentage=4), Material(fabric_type=None, name='carbon', percentage=6)], weight='215 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='meta-aramid', percentage=50), Material(fabric_type=None, name='viscose', percentage=50)], weight='120 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='modacrylic', percentage=39), Material(fabric_type=None, name='cordura®', percentage=28), Material(fabric_type=None, name='cotton', percentage=17), Material(fabric_type=None, name='aramid', percentage=15), Material(fabric_type=None, name='antistatic', percentage=1)], weight='270 g/m²')]
# code='#1673' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=65), Material(fabric_type=None, name='cotton', percentage=35)], weight='260g/m²')]
# code='#1800' category='JACKET/COAT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='220 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Mesh', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='367 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1801' category='JACKET/COAT' construction=[ConstructionElement(name='Material', colors=[], materials=[Material(fabric_type=None, name='recycled polyamide', percentage=100)], weight='175 g'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='cordura® polyamide', percentage=100)], weight='190 g'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='repreve® recycled polyester', percentage=90), Material(fabric_type=None, name='recycled polyester,  in body,  in sleeves, 60 g in hood', percentage=10)], weight='160 g'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#1830' category='JACKET/COAT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='137 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=100)], weight='205 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1860' category='JACKET/COAT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='protal', percentage=55), Material(fabric_type=None, name='cotton', percentage=44), Material(fabric_type=None, name='antistatic', percentage=1)], weight='265 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=40), Material(fabric_type=None, name='viscose fr', percentage=37), Material(fabric_type=None, name='regenerated viscose', percentage=22), Material(fabric_type=None, name='antistatic', percentage=1)], weight='180 g/m²'), ConstructionElement(name='Padding', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='110 g/m²')]
# code='#1902' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='69 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyester', percentage=64), Material(fabric_type=None, name='viscose', percentage=30), Material(fabric_type=None, name='elastane', percentage=6)], weight='380 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='repreve® recycled polyester', percentage=90), Material(fabric_type=None, name='polyester', percentage=10)], weight='120 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='69 g/m²')]
# code='#1908' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='70 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='95 g/m²')]
# code='#1915' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=94), Material(fabric_type=None, name=', elastane', percentage=6)], weight='178 g/m²'), ConstructionElement(name='Contrast 1 (backpanel)', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=92), Material(fabric_type=None, name='elastane', percentage=8)], weight='118 g/m²')]
# code='#1940' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=73), Material(fabric_type=None, name='polyurethane', percentage=20), Material(fabric_type=None, name='elastane schoeller®', percentage=7)], weight='220 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=84), Material(fabric_type=None, name='elastane', percentage=16)], weight='298 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type='Armortex®', name='polyamide', percentage=56), Material(fabric_type='Armortex®', name='elastane', percentage=26), Material(fabric_type='Armortex®', name='dupont™ kevlar® aramid fibers', percentage=18)], weight='380 g/m²')]
# code='#1948' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='69 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=88), Material(fabric_type=None, name='elastane', percentage=12)], weight='275 g/m²'), ConstructionElement(name='Stretch', colors=[], materials=[Material(fabric_type=None, name='nylon', percentage=84), Material(fabric_type=None, name='elastane', percentage=16)], weight='193 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='98 g/m²')]
# code='#1950' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=88), Material(fabric_type=None, name='elastane', percentage=12)], weight=''), ConstructionElement(name='Main 2', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight=''), ConstructionElement(name='Isolation', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight=''), ConstructionElement(name='Fill power 330 Lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='')]
# code='#1980' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='gore-tex polyester', percentage=100)], weight='145 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='gore-tex polyester', percentage=44), Material(fabric_type=None, name='polyamide', percentage=37), Material(fabric_type=None, name='elastane', percentage=19)], weight='215 g/m²')]
# code='#1981' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='gore-tex® polyester', percentage=100)], weight='140 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type='GORE-TEX®', name='polyester', percentage=44), Material(fabric_type='GORE-TEX®', name='polyamide', percentage=37), Material(fabric_type='GORE-TEX®', name='elastane', percentage=19)], weight='215 g/m²'), ConstructionElement(name='Cuff stretch', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=90), Material(fabric_type=None, name='elastane', percentage=10)], weight='253 g/m²'), ConstructionElement(name='Lining', colors=[], materials=[Material(fabric_type=None, name='solution dyed polyamide', percentage=100)], weight='65 g/m²'), ConstructionElement(name='Insulation', colors=[], materials=[Material(fabric_type=None, name='37.5® polyester', percentage=50), Material(fabric_type=None, name='repreve® recycled polyester', percentage=35), Material(fabric_type=None, name='polyester', percentage=15)], weight='120 g/m²'), ConstructionElement(name='Pocket lining', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='215 g/m²')]
# code='#1982' category='JACKET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide gore® windstopper®', percentage=94), Material(fabric_type=None, name='elastane', percentage=6)], weight='285 g/m²'), ConstructionElement(name='Contrast', colors=[], materials=[Material(fabric_type=None, name='polyamide cordura®', percentage=88), Material(fabric_type=None, name='elastane', percentage=12)], weight='270g/m²')]
# code='#2405' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=['9567'], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='140 g/m²')]
# code='#2410' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='200 g/m²')]
# code='#2411' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=91), Material(fabric_type=None, name='elastane', percentage=9)], weight='190 g/m²')]
# code='#2427' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='mulesing-free merino wool with kalendar finish, sm', percentage=100)], weight='160 g')]
# code='#2430' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='recycled polyester', percentage=66), Material(fabric_type=None, name='cotton ', percentage=34)], weight='195 g/m²')]
# code='#2431' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='recycled polyester', percentage=66), Material(fabric_type=None, name='cotton ', percentage=34)], weight='195 g/m²')]
# code='#2433' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='150 g/m²')]
# code='#2460' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=60), Material(fabric_type=None, name='cotton', percentage=38), Material(fabric_type=None, name='belltron™', percentage=2)], weight='215 g/m²')]
# code='#2461' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic', percentage=60), Material(fabric_type=None, name='cotton', percentage=37), Material(fabric_type=None, name='belltron™', percentage=3)], weight='230 g/m²')]
# code='#2462' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic', percentage=60), Material(fabric_type=None, name='cotton', percentage=38), Material(fabric_type=None, name='belltron®', percentage=2)], weight='230 g/m²')]
# code='#2467' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic', percentage=60), Material(fabric_type=None, name='cotton', percentage=38), Material(fabric_type=None, name='belltron™', percentage=2)], weight='215 g/m²')]
# code='#2476' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic', percentage=60), Material(fabric_type=None, name='cotton', percentage=37), Material(fabric_type=None, name='belltron™', percentage=3)], weight='230 g/m²')]
# code='#2496' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=['0400', '0900', '5800', '9500'], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='160 g/m²'), ConstructionElement(name='Main', colors=['2800'], materials=[Material(fabric_type=None, name='cotton', percentage=95), Material(fabric_type=None, name='viscose', percentage=5)], weight='160 g/m²')]
# code='#2497' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='160 g/m²')]
# code='#2498' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type='polyester', name='37.5® polyester', percentage=45), Material(fabric_type=None, name='polyester ', percentage=100)], weight='185 g/m²')]
# code='#2502' category='TSHIRT' construction=[ConstructionElement(name='100%Cotton,', colors=['2800'], materials=[Material(fabric_type=None, name='cotton', percentage=95), Material(fabric_type=None, name='viscose', percentage=5)], weight='160 g/m²')]
# code='#2504' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='200 g/m²')]
# code='#2505' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=['9567'], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='140 g/m²')]
# code='#2511' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=91), Material(fabric_type=None, name='elastane', percentage=9)], weight='190 g/m²')]
# code='#2512' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=['0400', '5800', '9500'], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='160 g/m²'), ConstructionElement(name='Main', colors=['2800'], materials=[Material(fabric_type=None, name='cotton', percentage=95), Material(fabric_type=None, name='viscose', percentage=5)], weight='160 g/m²')]
# code='#2516' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='160 g/m²')]
# code='#2517' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='organic cotton', percentage=100)], weight='200 g/m²')]
# code='#2518' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='160 g/m²')]
# code='#2519' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=61), Material(fabric_type=None, name='37.5® polyester', percentage=39)], weight='148 g/m²')]
# code='#2522' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=100)], weight='160 g/m²')]
# code='#2526' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='organic cotton', percentage=100)], weight='200 g/m²')]
# code='#2527' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='mulesing-free merino wool with calender finish', percentage=100)], weight='160 g/m²')]
# code='#2529' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cotton', percentage=95), Material(fabric_type=None, name='elastane', percentage=5)], weight='180 g/m²')]
# code='#2530' category='TSHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=100)], weight='150 g/m²')]
# ...
# code='#9465' category='UNDERWEAR/BRA' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=57), Material(fabric_type=None, name='cotton', percentage=36), Material(fabric_type=None, name='elastan', percentage=5), Material(fabric_type=None, name='belltron™', percentage=2)], weight='210 g/m²')]
# code='#9466' category='UNDERWEAR/PANTIES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=57), Material(fabric_type=None, name='cotton', percentage=36), Material(fabric_type=None, name='elastan', percentage=5), Material(fabric_type=None, name='belltron™', percentage=2)], weight='210 g/m²')]
# code='#9467' category='UNDERWEAR/BOXERS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic', percentage=57), Material(fabric_type=None, name='cotton', percentage=36), Material(fabric_type=None, name='elastan', percentage=5), Material(fabric_type=None, name='belltron™', percentage=2)], weight='210 g/m²')]
# code='#9468' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='viscose fr', percentage=49), Material(fabric_type=None, name='wool', percentage=49), Material(fabric_type=None, name='belltron™', percentage=2)], weight='210 g/m²')]
# code='#9469' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='wool', percentage=68), Material(fabric_type=None, name='modacrylic fr', percentage=30), Material(fabric_type=None, name='belltron™', percentage=2)], weight='370 g/m²')]
# code='#9476' category='SHIRT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='viscose fr', percentage=49), Material(fabric_type=None, name='wool', percentage=49), Material(fabric_type=None, name='belltron™', percentage=2)], weight='210 g/m²')]
# code='#9480' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='merino wool', percentage=55), Material(fabric_type=None, name='polyester', percentage=36), Material(fabric_type=None, name='poyamide', percentage=9)], weight='230 g/m²')]
# code='#9481' category='HOSIERY/LEGGINGS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='merino wool', percentage=55), Material(fabric_type=None, name='polyester', percentage=36), Material(fabric_type=None, name='poyamide', percentage=9)], weight='230 g/m²')]
# code='#9483' category='TSHIRT/LONG-SLEEVE' construction=[]
# code='#9484' category='HOSIERY/LEGGINGS' construction=[]
# code='#9485' category='TSHIRT/LONG-SLEEVE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='solution dyed recycled polyester', percentage=53), Material(fabric_type=None, name='polyester with bamboo charcoal', percentage=43), Material(fabric_type=None, name='elastane', percentage=4)], weight='250 g/m²')]
# code='#9486' category='HOSIERY/LEGGINGS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='solution dyed recycled polyester', percentage=53), Material(fabric_type=None, name='polyester with bamboo charcoal', percentage=43), Material(fabric_type=None, name='elastane', percentage=4)], weight='250 g/m²')]
# code='#9491' category='TSHIRT/LONG-SLEEVE' construction=[]
# code='#9492' category='HOSIERY/LEGGINGS' construction=[]
# code='#9566' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='full-gain leather, 0.8-1.0 mm thick', percentage=100)], weight='')]
# code='#9574' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=66), Material(fabric_type=None, name='polyester', percentage=17), Material(fabric_type=None, name='rubber', percentage=8), Material(fabric_type=None, name='polyurethane', percentage=5), Material(fabric_type=None, name='cotton', percentage=4)], weight='')]
# code='#9578' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=45), Material(fabric_type=None, name='polyester', percentage=30), Material(fabric_type=None, name='polyurethane', percentage=22), Material(fabric_type=None, name='reflective yarn', percentage=3)], weight='')]
# code='#9579' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=35), Material(fabric_type=None, name='polyester', percentage=27), Material(fabric_type=None, name='polyurethane', percentage=20), Material(fabric_type=None, name='rubber', percentage=8), Material(fabric_type=None, name='reflective yarn', percentage=5), Material(fabric_type=None, name='polyethylene', percentage=5)], weight='')]
# code='#9585' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type='Polyamide', name=', polyurethane', percentage=50), Material(fabric_type='Polyamide', name=', polyester', percentage=40), Material(fabric_type='Polyamide', name=', pvc', percentage=3), Material(fabric_type='Polyamide', name=', silicon', percentage=5), Material(fabric_type='Polyamide', name='', percentage=2)], weight='')]
# code='#9586' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=50), Material(fabric_type=None, name='polyurethane', percentage=40), Material(fabric_type=None, name='polyester', percentage=3), Material(fabric_type=None, name='pvc', percentage=5), Material(fabric_type=None, name='silicon', percentage=2)], weight='')]
# code='#9597' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=62), Material(fabric_type=None, name='polyester', percentage=16), Material(fabric_type=None, name='polyurethane', percentage=14), Material(fabric_type=None, name='rubber', percentage=8)], weight='')]
# code='#9598' category='GLOVES' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=62), Material(fabric_type=None, name='polyester', percentage=16), Material(fabric_type=None, name='polyurethane', percentage=14), Material(fabric_type=None, name='rubber', percentage=8)], weight='')]
# code='#9623' category='BAG/MEDIUM' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='ripstop polyamide', percentage=100)], weight='')]
# code='#9626' category='BAG/MEDIUM' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='ripstop polyamide', percentage=100)], weight='')]
# code='#9700' category='UNKNOWN' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='ripstop polyamide', percentage=100)], weight='')]
# code='#9716' category='UNKNOWN' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='ripstop polyamide', percentage=100)], weight='')]
# code='#9736' category='UNKNOWN' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='ripstop polyamide', percentage=100)], weight='')]
# code='#9746' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='thermoplastic polyurethane', percentage=100)], weight='')]
# code='#9751' category='ACCESSORY/KEYCHAIN' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9754' category='ACCESSORY/WALLET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9757' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic', percentage=39), Material(fabric_type=None, name='cordura®', percentage=28), Material(fabric_type=None, name='cotton', percentage=17), Material(fabric_type=None, name='aramid', percentage=15), Material(fabric_type=None, name='antistatic', percentage=1)], weight='270 g/m²')]
# code='#9759' category='ACCESSORY/WALLET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='abs plastic, polyester string', percentage=100)], weight='')]
# code='#9760' category='ACCESSORY/WALLET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='pvc, conforms to en 15777', percentage=100)], weight='')]
# code='#9762' category='UNKNOWN' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='pvc, conforms to en 15777', percentage=100)], weight='')]
# code='#9764' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#9766' category='ACCESSORY/WALLET' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='pvc', percentage=100)], weight='')]
# code='#9767' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9768' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9769' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9770' category='ACCESSORY/BELT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='nylon', percentage=100), Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='')]
# code='#9772' category='ACCESSORY/BELT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='nylon', percentage=100), Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#9775' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9776' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#9779' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=31), Material(fabric_type=None, name='modacrylic', percentage=28), Material(fabric_type=None, name='aramid kermel®', percentage=20), Material(fabric_type=None, name='cv fr', percentage=20), Material(fabric_type=None, name='antistatic', percentage=1)], weight='320 g/m²')]
# code='#9780' category='ACCESSORY/BELT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='nylon', percentage=100), Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='')]
# code='#9782' category='ACCESSORY/BELT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type='Belt in', name='nylon, pouches', percentage=100), Material(fabric_type='Belt in', name='polyamide', percentage=100)], weight='')]
# code='#9783' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic,  reinforcement:', percentage=1), Material(fabric_type=None, name='polyester', percentage=54), Material(fabric_type=None, name='aramide', percentage=24), Material(fabric_type=None, name='polyamide', percentage=13), Material(fabric_type=None, name='polyurethane', percentage=9)], weight='300g/m²')]
# code='#9785' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9786' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#9787' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic', percentage=1)], weight='300 g/m²'), ConstructionElement(name='Reinforcement', colors=[], materials=[Material(fabric_type=None, name='polyester', percentage=54), Material(fabric_type=None, name='aramide', percentage=24), Material(fabric_type=None, name='polyamide', percentage=13), Material(fabric_type=None, name='polyurethane', percentage=9)], weight='450 g/m²')]
# code='#9790' category='ACCESSORY/BELT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='nylon', percentage=100), Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='')]
# code='#9792' category='ACCESSORY/BELT' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='nylon', percentage=100)], weight='')]
# code='#9793' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic', percentage=1)], weight='300g/m²')]
# code='#9794' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='cordura®-polyamide', percentage=100)], weight='300 g/m²')]
# code='#9795' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='leather', percentage=100)], weight='')]
# code='#9796' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]
# code='#9797' category='PANTS' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='modacrylic fr', percentage=49), Material(fabric_type=None, name='cotton', percentage=42), Material(fabric_type=None, name='aramid', percentage=5), Material(fabric_type=None, name='polyamide', percentage=3), Material(fabric_type=None, name='antistatic', percentage=1)], weight='300 g/m²')]
# code='#9798' category='ACCESSORY/PHONE-CASE' construction=[ConstructionElement(name='Main', colors=[], materials=[Material(fabric_type=None, name='polyamide', percentage=100)], weight='')]

# %%
#Doublon #1100 et #1102
#code='#7512' category='SWEATER/HOODIE' construction=[ConstructionElement(name='82%cotton, 18%polyester, 280 g/m². 2X2 Rib', colors=['0400', '2800'], materials=[Material(fabric_type=None, name='cotton', percentage=97), Material(fabric_type=None, name='elastane', percentage=3)], weight='380 g/m²')]

# %%
parse_construction_details('"Main: 100% GORE-TEXÂ® polyester 140 g/mÂ². Contrast: GORE-TEXÂ® 44% polyester 37% polyamide 19% elastane 215 g/mÂ². Cuff stretch: 90% polyester 10% elastane, 253 g/mÂ².  Lining: 100% solution dyed polyamide 65 g/mÂ². Insulation: 50% 37.5Â® polyester, 35% REPREVEÂ® recycled polyester, 15% polyester, 120 g/mÂ². Pocket lining: 100% polyester, 215 g/mÂ². ')
# Out:
# [{'name': '"Main',
#   'materials': [{'fabric_type': None,
#     'name': 'gore-tex® polyester',
#     'percentage': 100}],
#   'weight': '140 g/m²',
#   'colors': []},
#  {'name': 'Contrast',
#   'materials': [{'fabric_type': 'GORE-TEX®',
#     'name': 'polyester',
#     'percentage': 44},
#    {'fabric_type': 'GORE-TEX®', 'name': 'polyamide', 'percentage': 37},
#    {'fabric_type': 'GORE-TEX®', 'name': 'elastane', 'percentage': 19}],
#   'weight': '215 g/m²',
#   'colors': []},
#  {'name': 'Cuff stretch',
#   'materials': [{'fabric_type': None, 'name': 'polyester', 'percentage': 90},
#    {'fabric_type': None, 'name': 'elastane', 'percentage': 10}],
#   'weight': '253 g/m²',
#   'colors': []},
#  {'name': 'Lining',
#   'materials': [{'fabric_type': None,
#     'name': 'solution dyed polyamide',
#     'percentage': 100}],
#   'weight': '65 g/m²',
#   'colors': []},
#  {'name': 'Insulation',
#   'materials': [{'fabric_type': None,
#     'name': '37.5® polyester',
#     'percentage': 50},
#    {'fabric_type': None,
#     'name': 'repreve® recycled polyester',
#     'percentage': 35},
#    {'fabric_type': None, 'name': 'polyester', 'percentage': 15}],
#   'weight': '120 g/m²',
#   'colors': []},
#  {'name': 'Pocket lining',
#   'materials': [{'fabric_type': None, 'name': 'polyester', 'percentage': 100}],
#   'weight': '215 g/m²',
#   'colors': []}]

# %%
import pandas as pd

# Let's assume 'garments' is the list of Garment objects parsed from the CSV,
# and each garment has a 'code', 'category', and a list 'construction' of ConstructionElement objects.
# Each ConstructionElement has 'name', 'materials' (list of strings), and 'weight'.

# Collect all possible construction element names across garments so that we know what columns to expect.
all_elements = set()
for garment in garments:
    for element in garment.construction:
        all_elements.add(element.name)

# Prepare rows for the DataFrame
rows = []
for garment in garments:
    # Start with code and category.
    row = {"code": garment.code, "category": garment.category}
    # For each construction element (like 'Main', 'Reinforcement', etc.), we add two columns:
    # one for the materials (joined into a single string) and one for the weight.
    # Initialize columns for all possible construction elements to empty strings.
    for element_name in all_elements:
        row[f"{element_name}_materials"] = ""
        row[f"{element_name}_weight"] = ""
    
    # Fill in the available construction element details.
    for element in garment.construction:
        row[f"{element.name}_materials"] = ", ".join(element.materials)
        row[f"{element.name}_weight"] = element.weight
    rows.append(row)

# Create the DataFrame.
df = pd.DataFrame(rows)
df
# Out:
#            code              category Reinforcement 1; knee pad_materials  \
# 0    product_id      product_category
# 1          #113                 PANTS
# 2          #212                 PANTS
# 3          #213                 PANTS
# 4          #214                 PANTS
# ..          ...                   ...                                 ...
# 569       #9794                 PANTS
# 570       #9795  ACCESSORY/PHONE-CASE
# 571       #9796  ACCESSORY/PHONE-CASE
# 572       #9797                 PANTS
# 573       #9798  ACCESSORY/PHONE-CASE
#
#     Reinforcement 1; knee pad_weight Contrast main_materials  \
# 0
# 1
# 2
# 3
# 4
# ..                               ...                     ...
# 569
# 570
# 571
# 572
# 573
#
#     Contrast main_weight Color_materials Color_weight Colour 3400_materials  \
# 0
# 1
# 2
# 3
# 4
# ..                   ...             ...          ...                   ...
# 569
# 570
# 571
# 572
# 573
#
#     Colour 3400_weight  ... Mesh_materials Mesh_weight Insulation_materials  \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
# ..                 ...  ...            ...         ...                  ...
# 569                     ...
# 570                     ...
# 571                     ...
# 572                     ...
# 573                     ...
#
#     Insulation_weight Pocket lining_materials Pocket lining_weight  \
# 0
# 1
# 2
# 3
# 4
# ..                ...                     ...                  ...
# 569
# 570
# 571
# 572
# 573
#
#     Colour 0455, 0466 / Main_materials Colour 0455, 0466 / Main_weight  \
# 0
# 1
# 2
# 3
# 4
# ..                                 ...                             ...
# 569
# 570
# 571
# 572
# 573
#
#     Lining_materials Lining_weight
# 0
# 1
# 2
# 3
# 4
# ..               ...           ...
# 569
# 570
# 571
# 572
# 573
#
# [574 rows x 154 columns]

# %%
a = list(df.columns)
(a)
# Out:
# ['code',
#  'category',
#  'Reinforcement 1; knee pad_materials',
#  'Reinforcement 1; knee pad_weight',
#  'Contrast main_materials',
#  'Contrast main_weight',
#  'Color_materials',
#  'Color_weight',
#  'Colour 3400_materials',
#  'Colour 3400_weight',
#  'Main Material_materials',
#  'Main Material_weight',
#  'Palm_materials',
#  'Palm_weight',
#  'Colors_materials',
#  'Colors_weight',
#  'Contrast fabric_materials',
#  'Contrast fabric_weight',
#  'Coating_materials',
#  'Coating_weight',
#  'Contrast 2 (armpit)_materials',
#  'Contrast 2 (armpit)_weight',
#  'Ripstop_materials',
#  'Ripstop_weight',
#  'Reinforcement 2; pockets_materials',
#  'Reinforcement 2; pockets_weight',
#  'Col 0400, 0900, 5800 and 9500_materials',
#  'Col 0400, 0900, 5800 and 9500_weight',
#  'Colours 0400, 0600, 4000, 9500_materials',
#  'Colours 0400, 0600, 4000, 9500_weight',
#  'Colour 0400, 9500_materials',
#  'Colour 0400, 9500_weight',
#  'Fill power 330\nLining_materials',
#  'Fill power 330\nLining_weight',
#  'Col 0400 and 2800_materials',
#  'Col 0400 and 2800_weight',
#  'Polartec® Power Stretch®_materials',
#  'Polartec® Power Stretch®_weight',
#  'Col 0400_materials',
#  'Col 0400_weight',
#  'Isolation_materials',
#  'Isolation_weight',
#  'Colour 2000/ Main_materials',
#  'Colour 2000/ Main_weight',
#  'Weight_materials',
#  'Weight_weight',
#  'Col 0400 and 3100_materials',
#  'Col 0400 and 3100_weight',
#  '2X2 Rib_materials',
#  '2X2 Rib_weight',
#  'Main_materials',
#  'Main_weight',
#  'Filling_materials',
#  'Filling_weight',
#  'Reinforcement_materials',
#  'Reinforcement_weight',
#  'Colour 2800_materials',
#  'Colour 2800_weight',
#  'Stretch_materials',
#  'Stretch_weight',
#  '2800_materials',
#  '2800_weight',
#  'Colours_materials',
#  'Colours_weight',
#  'Reinforcement 2_materials',
#  'Reinforcement 2_weight',
#  'Colour 9566 / Main_materials',
#  'Colour 9566 / Main_weight',
#  'Contrast 2_materials',
#  'Contrast 2_weight',
#  'Reinforcements_materials',
#  'Reinforcements_weight',
#  'Contrast 1_materials',
#  'Contrast 1_weight',
#  'Polartec® INSULATION_materials',
#  'Polartec® INSULATION_weight',
#  'Padding_materials',
#  'Padding_weight',
#  'Contrast_materials',
#  'Contrast_weight',
#  'Main Fabric_materials',
#  'Main Fabric_weight',
#  'Colour_materials',
#  'Colour_weight',
#  'Col 0400, 2800 and 3100_materials',
#  'Col 0400, 2800 and 3100_weight',
#  'Main face_materials',
#  'Main face_weight',
#  'Color 9567_materials',
#  'Color 9567_weight',
#  'reinforcement_materials',
#  'reinforcement_weight',
#  'Backing_materials',
#  'Backing_weight',
#  'Detail_materials',
#  'Detail_weight',
#  'Col 4500_materials',
#  'Col 4500_weight',
#  'Main 2_materials',
#  'Main 2_weight',
#  'Reinforcement 1_materials',
#  'Reinforcement 1_weight',
#  'Stretch fabric_materials',
#  'Stretch fabric_weight',
#  'Polartec®_materials',
#  'Polartec®_weight',
#  'Rib_materials',
#  'Rib_weight',
#  'Dipping_materials',
#  'Dipping_weight',
#  'Main fabric_materials',
#  'Main fabric_weight',
#  'Contrast stretch back thigh panels_materials',
#  'Contrast stretch back thigh panels_weight',
#  'Material_materials',
#  'Material_weight',
#  'Reinforcement Knee_materials',
#  'Reinforcement Knee_weight',
#  'Colour 0400, 1604, 3904, 9504_materials',
#  'Colour 0400, 1604, 3904, 9504_weight',
#  'Details front panels and gusset_materials',
#  'Details front panels and gusset_weight',
#  'Shell_materials',
#  'Shell_weight',
#  'Cuff stretch_materials',
#  'Cuff stretch_weight',
#  'Collar lining_materials',
#  'Collar lining_weight',
#  'Contrast 1 (backpanel)_materials',
#  'Contrast 1 (backpanel)_weight',
#  'Pile_materials',
#  'Pile_weight',
#  'Colour 0904; Main_materials',
#  'Colour 0904; Main_weight',
#  'Col 2800_materials',
#  'Col 2800_weight',
#  'Colours 0400, 1600, 3900, 9500_materials',
#  'Colours 0400, 1600, 3900, 9500_weight',
#  'Colour 2804_materials',
#  'Colour 2804_weight',
#  'Colour 0400, 0600, 4000 and 9500_materials',
#  'Colour 0400, 0600, 4000 and 9500_weight',
#  'Col 0400, 5800 and 9500_materials',
#  'Col 0400, 5800 and 9500_weight',
#  'Mesh_materials',
#  'Mesh_weight',
#  'Insulation_materials',
#  'Insulation_weight',
#  'Pocket lining_materials',
#  'Pocket lining_weight',
#  'Colour 0455, 0466 / Main_materials',
#  'Colour 0455, 0466 / Main_weight',
#  'Lining_materials',
#  'Lining_weight']
